# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load CSV File
zermatt_ml_df = pd.read_csv('./Zermatt_SnowFall.csv')
zermatt_ml_df
# Out:
#     year  total_snowfall
# 0   1990          423.71
# 1   1991          310.35
# 2   1992          415.46
# 3   1993          483.60
# 4   1994          482.85
# 5   1995          774.19
# 6   1996          721.70
# 7   1997          418.02
# 8   1998          371.87
# 9   1999          782.60
# 10  2000          412.46
# 11  2001          359.02
# 12  2002          654.61
# 13  2003          428.55
# 14  2004          658.82
# 15  2005          335.56
# 16  2006          396.54
# 17  2007          525.92
# 18  2008          572.87
# 19  2009          609.40
# 20  2010          491.01
# 21  2011          343.65
# 22  2012          737.96
# 23  2013          739.49
# 24  2014          810.34
# 25  2015          354.28
# 26  2016          492.37
# 27  2017          672.19
# 28  2018         1149.25
# 29  2019          792.29
# 30  2020          445.40
# 31  2021          743.54
# 32  2022          315.04

# %%
# Drop the last row, as 2022 isn't finished yet
zermatt_ml_df.drop(zermatt_ml_df.tail(1).index, inplace=True)
zermatt_ml_df
# Out:
#     year  total_snowfall
# 0   1990          423.71
# 1   1991          310.35
# 2   1992          415.46
# 3   1993          483.60
# 4   1994          482.85
# 5   1995          774.19
# 6   1996          721.70
# 7   1997          418.02
# 8   1998          371.87
# 9   1999          782.60
# 10  2000          412.46
# 11  2001          359.02
# 12  2002          654.61
# 13  2003          428.55
# 14  2004          658.82
# 15  2005          335.56
# 16  2006          396.54
# 17  2007          525.92
# 18  2008          572.87
# 19  2009          609.40
# 20  2010          491.01
# 21  2011          343.65
# 22  2012          737.96
# 23  2013          739.49
# 24  2014          810.34
# 25  2015          354.28
# 26  2016          492.37
# 27  2017          672.19
# 28  2018         1149.25
# 29  2019          792.29
# 30  2020          445.40
# 31  2021          743.54

# %%
# Visually Inspect the relationship between Snowfall and Years
plt.scatter(zermatt_ml_df.year, zermatt_ml_df.total_snowfall)
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
# Format data to meet requirements of the Scikit-learn library
X = zermatt_ml_df.year.values.reshape(-1, 1)

# %%
# Assign the y value
y = zermatt_ml_df.total_snowfall

# %%
# Create an instance of the linear regression model
model = LinearRegression()

# %%
# Fit the model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Generate predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (32,)

# %%
# Plot the predictions as a red line against the data points
plt.scatter(X,y)
plt.plot(X, y_pred, color='red')
plt.title("Predicting Snowfall in Zermatt")
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
#Examine slope and y-intercept
print(model.coef_)
print(model.intercept_)
# Out:
# [8.10195931]
# -15688.795960410564
