# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load CSV File
furano_ml_df = pd.read_csv('./Furano_SnowFall.csv')
furano_ml_df
# Out:
#     year  total_snowfall
# 0   1990          205.96
# 1   1991          299.03
# 2   1992          262.81
# 3   1993          398.81
# 4   1994          346.89
# 5   1995          316.40
# 6   1996          416.38
# 7   1997          274.44
# 8   1998          289.32
# 9   1999          328.74
# 10  2000          518.98
# 11  2001          291.72
# 12  2002          385.04
# 13  2003          293.34
# 14  2004          449.14
# 15  2005          354.71
# 16  2006          365.05
# 17  2007          353.48
# 18  2008          351.84
# 19  2009          478.85
# 20  2010          375.83
# 21  2011          390.42
# 22  2012          443.62
# 23  2013          479.81
# 24  2014          364.67
# 25  2015          416.76
# 26  2016          478.53
# 27  2017          397.96
# 28  2018          389.11
# 29  2019          350.80
# 30  2020          311.85
# 31  2021          365.18
# 32  2022          243.56

# %%
# Drop the last row, as 2022 isn't finished yet
furano_ml_df.drop(furano_ml_df.tail(1).index, inplace=True)
furano_ml_df
# Out:
#     year  total_snowfall
# 0   1990          205.96
# 1   1991          299.03
# 2   1992          262.81
# 3   1993          398.81
# 4   1994          346.89
# 5   1995          316.40
# 6   1996          416.38
# 7   1997          274.44
# 8   1998          289.32
# 9   1999          328.74
# 10  2000          518.98
# 11  2001          291.72
# 12  2002          385.04
# 13  2003          293.34
# 14  2004          449.14
# 15  2005          354.71
# 16  2006          365.05
# 17  2007          353.48
# 18  2008          351.84
# 19  2009          478.85
# 20  2010          375.83
# 21  2011          390.42
# 22  2012          443.62
# 23  2013          479.81
# 24  2014          364.67
# 25  2015          416.76
# 26  2016          478.53
# 27  2017          397.96
# 28  2018          389.11
# 29  2019          350.80
# 30  2020          311.85
# 31  2021          365.18

# %%
# Visually Inspect the relationship between Snowfall and Years
plt.scatter(furano_ml_df.year, furano_ml_df.total_snowfall)
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
# Format data to meet requirements of the Scikit-learn library
X = furano_ml_df.year.values.reshape(-1, 1)

# %%
# Assign the y value
y = furano_ml_df.total_snowfall

# %%
# Create an instance of the linear regression model
model = LinearRegression()

# %%
# Fit the model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Generate predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (32,)

# %%
# Plot the predictions as a red line against the data points
plt.scatter(X,y)
plt.plot(X, y_pred, color='red')
plt.title("Predicting Snowfall in Furano")
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
#Examine slope and y-intercept
print(model.coef_)
print(model.intercept_)
# Out:
# [3.28582295]
# -6222.671983137832
