# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load CSV File
tiffindell_ml_df = pd.read_csv('./Tiffindell_SnowFall.csv')
tiffindell_ml_df
# Out:
#     year  total_snowfall
# 0   1990           47.16
# 1   1991           13.24
# 2   1992           13.55
# 3   1993           10.05
# 4   1994           54.50
# 5   1995           10.65
# 6   1996           38.05
# 7   1997          107.44
# 8   1998           43.52
# 9   1999            9.80
# 10  2000           44.69
# 11  2001           43.31
# 12  2002          124.48
# 13  2003           18.27
# 14  2004           27.77
# 15  2005            3.64
# 16  2006          138.70
# 17  2007           47.01
# 18  2008           29.47
# 19  2009           51.08
# 20  2010           28.63
# 21  2011           94.44
# 22  2012          113.91
# 23  2013           15.61
# 24  2014           18.38
# 25  2015           40.22
# 26  2016           67.90
# 27  2017           67.88
# 28  2018           37.88
# 29  2019           12.01
# 30  2020           26.55
# 31  2021           45.61
# 32  2022           13.62

# %%
# Drop the last row, as 2022 isn't finished yet
tiffindell_ml_df.drop(tiffindell_ml_df.tail(1).index, inplace=True)
tiffindell_ml_df
# Out:
#     year  total_snowfall
# 0   1990           47.16
# 1   1991           13.24
# 2   1992           13.55
# 3   1993           10.05
# 4   1994           54.50
# 5   1995           10.65
# 6   1996           38.05
# 7   1997          107.44
# 8   1998           43.52
# 9   1999            9.80
# 10  2000           44.69
# 11  2001           43.31
# 12  2002          124.48
# 13  2003           18.27
# 14  2004           27.77
# 15  2005            3.64
# 16  2006          138.70
# 17  2007           47.01
# 18  2008           29.47
# 19  2009           51.08
# 20  2010           28.63
# 21  2011           94.44
# 22  2012          113.91
# 23  2013           15.61
# 24  2014           18.38
# 25  2015           40.22
# 26  2016           67.90
# 27  2017           67.88
# 28  2018           37.88
# 29  2019           12.01
# 30  2020           26.55
# 31  2021           45.61

# %%
# Visually Inspect the relationship between Snowfall and Years
plt.scatter(tiffindell_ml_df.year, tiffindell_ml_df.total_snowfall)
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
# Format data to meet requirements of the Scikit-learn library
X = tiffindell_ml_df.year.values.reshape(-1, 1)

# %%
# Assign the y value
y = tiffindell_ml_df.total_snowfall

# %%
# Create an instance of the linear regression model
model = LinearRegression()

# %%
# Fit the model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Generate predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (32,)

# %%
# Plot the predictions as a red line against the data points
plt.scatter(X,y)
plt.plot(X, y_pred, color='red')
plt.title("Predicting Snowfall in Tiffindell")
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
#Examine slope and y-intercept
print(model.coef_)
print(model.intercept_)
# Out:
# [0.3875]
# -731.9625000000001
