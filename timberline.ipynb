# %% [markdown]
# ### Import Dependencies

# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from config import db_password

# %%
timberline_df = pd.read_csv('./timberline.csv')

# %%
timberline_df
# Out:
#                 dt                         dt_iso  timezone         city_name  \
# 0        631152000  1990-01-01 00:00:00 +0000 UTC    -28800  Timberline Lodge
# 1        631155600  1990-01-01 01:00:00 +0000 UTC    -28800  Timberline Lodge
# 2        631159200  1990-01-01 02:00:00 +0000 UTC    -28800  Timberline Lodge
# 3        631162800  1990-01-01 03:00:00 +0000 UTC    -28800  Timberline Lodge
# 4        631166400  1990-01-01 04:00:00 +0000 UTC    -28800  Timberline Lodge
# ...            ...                            ...       ...               ...
# 287587  1666465200  2022-10-22 19:00:00 +0000 UTC    -25200  Timberline Lodge
# 287588  1666468800  2022-10-22 20:00:00 +0000 UTC    -25200  Timberline Lodge
# 287589  1666472400  2022-10-22 21:00:00 +0000 UTC    -25200  Timberline Lodge
# 287590  1666476000  2022-10-22 22:00:00 +0000 UTC    -25200  Timberline Lodge
# 287591  1666479600  2022-10-22 23:00:00 +0000 UTC    -25200  Timberline Lodge
#
#               lat         lon   temp  dew_point  feels_like  temp_min  ...  \
# 0       45.331128 -121.711006  36.03      34.21       29.80     36.03  ...
# 1       45.331128 -121.711006  36.28      34.47       30.67     36.28  ...
# 2       45.331128 -121.711006  33.69      32.41       27.90     33.69  ...
# 3       45.331128 -121.711006  34.05      32.77       28.47     34.05  ...
# 4       45.331128 -121.711006  34.21      32.94       28.67     34.21  ...
# ...           ...         ...    ...        ...         ...       ...  ...
# 287587  45.331128 -121.711006  30.90      29.55       18.30     28.22  ...
# 287588  45.331128 -121.711006  30.52      29.19       17.92     28.06  ...
# 287589  45.331128 -121.711006  29.62      28.29       17.02     27.95  ...
# 287590  45.331128 -121.711006  29.91      28.58       17.31     28.85  ...
# 287591  45.331128 -121.711006  30.34      29.01       17.74     28.78  ...
#
#         wind_gust  rain_1h  rain_3h  snow_1h  snow_3h  clouds_all  weather_id  \
# 0             NaN     0.31      NaN      NaN      NaN          76         500
# 1             NaN     0.27      NaN      NaN      NaN          92         500
# 2             NaN      NaN      NaN     0.21      NaN          98         600
# 3             NaN      NaN      NaN     0.19      NaN          97         600
# 4             NaN      NaN      NaN     0.19      NaN          96         600
# ...           ...      ...      ...      ...      ...         ...         ...
# 287587      45.99      NaN      NaN     0.76      NaN          92         601
# 287588      40.00      NaN      NaN     1.52      NaN          87         601
# 287589      44.00      NaN      NaN     1.78      NaN          87         601
# 287590      45.99      NaN      NaN     1.27      NaN          87         601
# 287591      45.99      NaN      NaN     1.52      NaN          61         601
#
#         weather_main  weather_description  weather_icon
# 0               Rain           light rain           10d
# 1               Rain           light rain           10n
# 2               Snow           light snow           13n
# 3               Snow           light snow           13n
# 4               Snow           light snow           13n
# ...              ...                  ...           ...
# 287587          Snow                 snow           13d
# 287588          Snow                 snow           13d
# 287589          Snow                 snow           13d
# 287590          Snow                 snow           13d
# 287591          Snow                 snow           13d
#
# [287592 rows x 27 columns]

# %% [markdown]
# ### Clean Dataset

# %%
# Drop irrevelant columns
timberline_df = timberline_df.drop(columns=['timezone', 'lat', 'lon', 'dew_point', 'feels_like', 'pressure', 'sea_level', 'grnd_level', 'wind_speed', 'wind_deg', 'wind_gust', 'rain_1h', 'rain_3h', 'snow_3h', 'clouds_all', 'weather_id', 'weather_icon'])
# Fill NaN with 0
timberline_df = timberline_df.fillna(0)

# %%
timberline_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287592 entries, 0 to 287591
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dt                   287592 non-null  int64
#  1   dt_iso               287592 non-null  object
#  2   city_name            287592 non-null  object
#  3   temp                 287592 non-null  float64
#  4   temp_min             287592 non-null  float64
#  5   temp_max             287592 non-null  float64
#  6   humidity             287592 non-null  int64
#  7   snow_1h              287592 non-null  float64
#  8   weather_main         287592 non-null  object
#  9   weather_description  287592 non-null  object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 21.9+ MB

# %%
# Convert dt to usable Datetime for index
datetime_info =  pd.to_datetime(timberline_df['dt'],unit='s')

# %%
# Set the index as datetime
timberline_datetime_index = timberline_df.set_index(datetime_info)
timberline_datetime_index
# Out:
#                              dt                         dt_iso  \
# dt
# 1990-01-01 00:00:00   631152000  1990-01-01 00:00:00 +0000 UTC
# 1990-01-01 01:00:00   631155600  1990-01-01 01:00:00 +0000 UTC
# 1990-01-01 02:00:00   631159200  1990-01-01 02:00:00 +0000 UTC
# 1990-01-01 03:00:00   631162800  1990-01-01 03:00:00 +0000 UTC
# 1990-01-01 04:00:00   631166400  1990-01-01 04:00:00 +0000 UTC
# ...                         ...                            ...
# 2022-10-22 19:00:00  1666465200  2022-10-22 19:00:00 +0000 UTC
# 2022-10-22 20:00:00  1666468800  2022-10-22 20:00:00 +0000 UTC
# 2022-10-22 21:00:00  1666472400  2022-10-22 21:00:00 +0000 UTC
# 2022-10-22 22:00:00  1666476000  2022-10-22 22:00:00 +0000 UTC
# 2022-10-22 23:00:00  1666479600  2022-10-22 23:00:00 +0000 UTC
#
#                             city_name   temp  temp_min  temp_max  humidity  \
# dt
# 1990-01-01 00:00:00  Timberline Lodge  36.03     36.03     36.03        93
# 1990-01-01 01:00:00  Timberline Lodge  36.28     36.28     36.28        93
# 1990-01-01 02:00:00  Timberline Lodge  33.69     33.69     33.69        95
# 1990-01-01 03:00:00  Timberline Lodge  34.05     34.05     34.05        95
# 1990-01-01 04:00:00  Timberline Lodge  34.21     34.21     34.21        95
# ...                               ...    ...       ...       ...       ...
# 2022-10-22 19:00:00  Timberline Lodge  30.90     28.22     34.79        94
# 2022-10-22 20:00:00  Timberline Lodge  30.52     28.06     35.76        94
# 2022-10-22 21:00:00  Timberline Lodge  29.62     27.95     30.87        94
# 2022-10-22 22:00:00  Timberline Lodge  29.91     28.85     32.41        94
# 2022-10-22 23:00:00  Timberline Lodge  30.34     28.78     32.20        94
#
#                      snow_1h weather_main weather_description
# dt
# 1990-01-01 00:00:00     0.00         Rain          light rain
# 1990-01-01 01:00:00     0.00         Rain          light rain
# 1990-01-01 02:00:00     0.21         Snow          light snow
# 1990-01-01 03:00:00     0.19         Snow          light snow
# 1990-01-01 04:00:00     0.19         Snow          light snow
# ...                      ...          ...                 ...
# 2022-10-22 19:00:00     0.76         Snow                snow
# 2022-10-22 20:00:00     1.52         Snow                snow
# 2022-10-22 21:00:00     1.78         Snow                snow
# 2022-10-22 22:00:00     1.27         Snow                snow
# 2022-10-22 23:00:00     1.52         Snow                snow
#
# [287592 rows x 10 columns]

# %%
# Resample data to reduce 24 hourly rows to 1 daily row - also remove columns not needed 
# (dt, dt_iso, city_name, weather_main, weather_description)
resampled_df = timberline_datetime_index.resample('D').agg({'temp': 'mean', 'temp_min' : 'mean', 'temp_max' : 'mean', 'humidity' : 'mean', 'snow_1h' : 'sum'})

# %%
resampled_df
# Out:
#                  temp   temp_min   temp_max   humidity  snow_1h
# dt
# 1990-01-01  32.980417  32.980417  32.980417  95.000000    12.10
# 1990-01-02  27.535833  27.535833  27.535833  91.500000     9.90
# 1990-01-03  30.131250  30.131250  30.131250  91.083333     0.53
# 1990-01-04  34.822083  34.822083  34.822083  91.791667     4.85
# 1990-01-05  38.994167  38.994167  38.994167  94.333333     0.00
# ...               ...        ...        ...        ...      ...
# 2022-10-18  48.152917  42.926250  52.189167  48.583333     0.00
# 2022-10-19  49.899167  45.100417  54.120000  42.875000     0.00
# 2022-10-20  49.231250  44.384583  54.397500  36.458333     0.00
# 2022-10-21  39.027917  34.692083  41.542083  74.416667     0.25
# 2022-10-22  31.549583  26.871667  33.675000  94.625000    25.65
#
# [11983 rows x 5 columns]

# %%
# Rename 'snow_1h' column to 'snowfall'
finished_df = resampled_df.rename(columns={"snow_1h" : "snowfall"})
finished_df
# Out:
#                  temp   temp_min   temp_max   humidity  snowfall
# dt
# 1990-01-01  32.980417  32.980417  32.980417  95.000000     12.10
# 1990-01-02  27.535833  27.535833  27.535833  91.500000      9.90
# 1990-01-03  30.131250  30.131250  30.131250  91.083333      0.53
# 1990-01-04  34.822083  34.822083  34.822083  91.791667      4.85
# 1990-01-05  38.994167  38.994167  38.994167  94.333333      0.00
# ...               ...        ...        ...        ...       ...
# 2022-10-18  48.152917  42.926250  52.189167  48.583333      0.00
# 2022-10-19  49.899167  45.100417  54.120000  42.875000      0.00
# 2022-10-20  49.231250  44.384583  54.397500  36.458333      0.00
# 2022-10-21  39.027917  34.692083  41.542083  74.416667      0.25
# 2022-10-22  31.549583  26.871667  33.675000  94.625000     25.65
#
# [11983 rows x 5 columns]

# %%
# Round all columns to two decimal places
finished_df = finished_df[['temp', 'temp_min', 'temp_max', 'humidity', 'snowfall']].round(2)
finished_df
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  32.98     32.98     32.98     95.00     12.10
# 1990-01-02  27.54     27.54     27.54     91.50      9.90
# 1990-01-03  30.13     30.13     30.13     91.08      0.53
# 1990-01-04  34.82     34.82     34.82     91.79      4.85
# 1990-01-05  38.99     38.99     38.99     94.33      0.00
# ...           ...       ...       ...       ...       ...
# 2022-10-18  48.15     42.93     52.19     48.58      0.00
# 2022-10-19  49.90     45.10     54.12     42.88      0.00
# 2022-10-20  49.23     44.38     54.40     36.46      0.00
# 2022-10-21  39.03     34.69     41.54     74.42      0.25
# 2022-10-22  31.55     26.87     33.68     94.62     25.65
#
# [11983 rows x 5 columns]

# %% [markdown]
# ### Export and Load into Postgres

# %%
# Export to CSV
finished_df.to_csv('./cleaned_timberline_df.csv')

# %%
# db_string used to connect to postgres
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/snow_data"

# %%
# create a Database engine to connect to postgres using the db_string
engine = create_engine(db_string)

# %%
finished_df.to_sql(name='timberline', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 finished_df.to_sql(name='timberline', con=engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1732, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1682 """
#    1683 Write records stored in a DataFrame to a SQL database.
#    1684
#    (...)
#    1728     Any additional kwargs are passed to the engine.
#    1729 """
#    1730 sql_engine = get_engine(engine)
# -> 1732 table = self.prep_table(
#    1733     frame=frame,
#    1734     name=name,
#    1735     if_exists=if_exists,
#    1736     index=index,
#    1737     index_label=index_label,
#    1738     schema=schema,
#    1739     dtype=dtype,
#    1740 )
#    1742 total_inserted = sql_engine.insert_records(
#    1743     table=table,
#    1744     con=self.connectable,
#    (...)
#    1751     **engine_kwargs,
#    1752 )
#    1754 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:834, in SQLTable.create(self)
#     832 if self.exists():
#     833     if self.if_exists == "fail":
# --> 834         raise ValueError(f"Table '{self.name}' already exists.")
#     835     elif self.if_exists == "replace":
#     836         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'timberline' already exists.

# %% [markdown]
# ### Import and minor clean additional datasets to load into postgres

# %%
#Import Furano data
furano_df = pd.read_csv('./cleaned_Furano_Ski_Resort_df.csv')
furano_df
# Out:
#                dt   temp  temp_min  temp_max  humidity  snowfall
# 0      1990-01-01  16.66     15.24     18.03     89.33      0.00
# 1      1990-01-02  17.54     14.36     21.16     86.83      0.00
# 2      1990-01-03  19.62     17.89     23.17     89.96      0.00
# 3      1990-01-04  19.10     17.63     21.53     85.96      1.48
# 4      1990-01-05  16.52     14.75     19.98     81.33      0.36
# ...           ...    ...       ...       ...       ...       ...
# 11978  2022-10-18  37.61     36.47     38.96     90.17      0.00
# 11979  2022-10-19  39.69     38.54     41.30     85.83      0.00
# 11980  2022-10-20  45.09     43.85     47.02     81.12      0.00
# 11981  2022-10-21  51.45     50.26     53.24     82.42      0.00
# 11982  2022-10-22  49.91     48.95     51.98     88.04      0.00
#
# [11983 rows x 6 columns]

# %%
furano_df.to_sql(name='furano', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 furano_df.to_sql(name='furano', con=engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1732, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1682 """
#    1683 Write records stored in a DataFrame to a SQL database.
#    1684
#    (...)
#    1728     Any additional kwargs are passed to the engine.
#    1729 """
#    1730 sql_engine = get_engine(engine)
# -> 1732 table = self.prep_table(
#    1733     frame=frame,
#    1734     name=name,
#    1735     if_exists=if_exists,
#    1736     index=index,
#    1737     index_label=index_label,
#    1738     schema=schema,
#    1739     dtype=dtype,
#    1740 )
#    1742 total_inserted = sql_engine.insert_records(
#    1743     table=table,
#    1744     con=self.connectable,
#    (...)
#    1751     **engine_kwargs,
#    1752 )
#    1754 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:834, in SQLTable.create(self)
#     832 if self.exists():
#     833     if self.if_exists == "fail":
# --> 834         raise ValueError(f"Table '{self.name}' already exists.")
#     835     elif self.if_exists == "replace":
#     836         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'furano' already exists.

# %%
#import Craigieburn data
craigieburn_df = pd.read_csv('./cleaned_Craigieburn_Valley_df.csv')
craigieburn_df
# Out:
#                dt   temp  temp_min  temp_max  humidity  snowfall
# 0      1990-01-01  48.73     48.73     48.73     71.79       0.0
# 1      1990-01-02  49.51     49.51     49.51     81.71       0.0
# 2      1990-01-03  50.30     50.30     50.30     75.50       0.0
# 3      1990-01-04  47.45     47.45     47.45     80.33       0.0
# 4      1990-01-05  44.14     44.14     44.14     79.08       0.0
# ...           ...    ...       ...       ...       ...       ...
# 11978  2022-10-18  39.62     39.62     39.62     72.33       0.0
# 11979  2022-10-19  42.28     42.28     42.28     68.96       0.0
# 11980  2022-10-20  41.10     41.10     41.10     71.50       0.0
# 11981  2022-10-21  39.14     39.14     39.14     71.92       0.0
# 11982  2022-10-22  50.54     50.54     50.54     57.54       0.0
#
# [11983 rows x 6 columns]

# %%
craigieburn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11983 entries, 0 to 11982
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   dt        11983 non-null  object
#  1   temp      11983 non-null  float64
#  2   temp_min  11983 non-null  float64
#  3   temp_max  11983 non-null  float64
#  4   humidity  11983 non-null  float64
#  5   snowfall  11983 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 561.8+ KB

# %%
# Clean dt column to be date format xxxx/xx/xx
craigieburn_datetime = pd.to_datetime(craigieburn_df['dt'])

# %%
# Clean (set index as date)
craigieburn_df = craigieburn_df.set_index(craigieburn_datetime)
craigieburn_df
# Out:
#                     dt   temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  1990-01-01  48.73     48.73     48.73     71.79       0.0
# 1990-01-02  1990-01-02  49.51     49.51     49.51     81.71       0.0
# 1990-01-03  1990-01-03  50.30     50.30     50.30     75.50       0.0
# 1990-01-04  1990-01-04  47.45     47.45     47.45     80.33       0.0
# 1990-01-05  1990-01-05  44.14     44.14     44.14     79.08       0.0
# ...                ...    ...       ...       ...       ...       ...
# 2022-10-18  2022-10-18  39.62     39.62     39.62     72.33       0.0
# 2022-10-19  2022-10-19  42.28     42.28     42.28     68.96       0.0
# 2022-10-20  2022-10-20  41.10     41.10     41.10     71.50       0.0
# 2022-10-21  2022-10-21  39.14     39.14     39.14     71.92       0.0
# 2022-10-22  2022-10-22  50.54     50.54     50.54     57.54       0.0
#
# [11983 rows x 6 columns]

# %%
craigieburn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11983 entries, 1990-01-01 to 2022-10-22
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   dt        11983 non-null  object
#  1   temp      11983 non-null  float64
#  2   temp_min  11983 non-null  float64
#  3   temp_max  11983 non-null  float64
#  4   humidity  11983 non-null  float64
#  5   snowfall  11983 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 655.3+ KB

# %%
# Drop dt Column
craigieburn_df = craigieburn_df.drop(columns=['dt'])

# %%
craigieburn_df
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  48.73     48.73     48.73     71.79       0.0
# 1990-01-02  49.51     49.51     49.51     81.71       0.0
# 1990-01-03  50.30     50.30     50.30     75.50       0.0
# 1990-01-04  47.45     47.45     47.45     80.33       0.0
# 1990-01-05  44.14     44.14     44.14     79.08       0.0
# ...           ...       ...       ...       ...       ...
# 2022-10-18  39.62     39.62     39.62     72.33       0.0
# 2022-10-19  42.28     42.28     42.28     68.96       0.0
# 2022-10-20  41.10     41.10     41.10     71.50       0.0
# 2022-10-21  39.14     39.14     39.14     71.92       0.0
# 2022-10-22  50.54     50.54     50.54     57.54       0.0
#
# [11983 rows x 5 columns]

# %%
craigieburn_df.to_sql(name='craigieburn', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 craigieburn_df.to_sql(name='craigieburn', con=engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1732, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1682 """
#    1683 Write records stored in a DataFrame to a SQL database.
#    1684
#    (...)
#    1728     Any additional kwargs are passed to the engine.
#    1729 """
#    1730 sql_engine = get_engine(engine)
# -> 1732 table = self.prep_table(
#    1733     frame=frame,
#    1734     name=name,
#    1735     if_exists=if_exists,
#    1736     index=index,
#    1737     index_label=index_label,
#    1738     schema=schema,
#    1739     dtype=dtype,
#    1740 )
#    1742 total_inserted = sql_engine.insert_records(
#    1743     table=table,
#    1744     con=self.connectable,
#    (...)
#    1751     **engine_kwargs,
#    1752 )
#    1754 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:834, in SQLTable.create(self)
#     832 if self.exists():
#     833     if self.if_exists == "fail":
# --> 834         raise ValueError(f"Table '{self.name}' already exists.")
#     835     elif self.if_exists == "replace":
#     836         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'craigieburn' already exists.

# %%
# Import Furano Data
furano_df = pd.read_csv('./cleaned_Furano_Ski_resort_df.csv')
furano_df
# Out:
#                dt   temp  temp_min  temp_max  humidity  snowfall
# 0      1990-01-01  16.66     15.24     18.03     89.33      0.00
# 1      1990-01-02  17.54     14.36     21.16     86.83      0.00
# 2      1990-01-03  19.62     17.89     23.17     89.96      0.00
# 3      1990-01-04  19.10     17.63     21.53     85.96      1.48
# 4      1990-01-05  16.52     14.75     19.98     81.33      0.36
# ...           ...    ...       ...       ...       ...       ...
# 11978  2022-10-18  37.61     36.47     38.96     90.17      0.00
# 11979  2022-10-19  39.69     38.54     41.30     85.83      0.00
# 11980  2022-10-20  45.09     43.85     47.02     81.12      0.00
# 11981  2022-10-21  51.45     50.26     53.24     82.42      0.00
# 11982  2022-10-22  49.91     48.95     51.98     88.04      0.00
#
# [11983 rows x 6 columns]

# %%
# dtcolumn to date xxxx/xx/xx
furano_datetime = pd.to_datetime(furano_df['dt'])

# %%
# Set Date as index
furano_df = furano_df.set_index(furano_datetime)
furano_df
# Out:
#                     dt   temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  1990-01-01  16.66     15.24     18.03     89.33      0.00
# 1990-01-02  1990-01-02  17.54     14.36     21.16     86.83      0.00
# 1990-01-03  1990-01-03  19.62     17.89     23.17     89.96      0.00
# 1990-01-04  1990-01-04  19.10     17.63     21.53     85.96      1.48
# 1990-01-05  1990-01-05  16.52     14.75     19.98     81.33      0.36
# ...                ...    ...       ...       ...       ...       ...
# 2022-10-18  2022-10-18  37.61     36.47     38.96     90.17      0.00
# 2022-10-19  2022-10-19  39.69     38.54     41.30     85.83      0.00
# 2022-10-20  2022-10-20  45.09     43.85     47.02     81.12      0.00
# 2022-10-21  2022-10-21  51.45     50.26     53.24     82.42      0.00
# 2022-10-22  2022-10-22  49.91     48.95     51.98     88.04      0.00
#
# [11983 rows x 6 columns]

# %%
# Drop dt column
furano_df = furano_df.drop(columns=['dt'])
furano_df
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  16.66     15.24     18.03     89.33      0.00
# 1990-01-02  17.54     14.36     21.16     86.83      0.00
# 1990-01-03  19.62     17.89     23.17     89.96      0.00
# 1990-01-04  19.10     17.63     21.53     85.96      1.48
# 1990-01-05  16.52     14.75     19.98     81.33      0.36
# ...           ...       ...       ...       ...       ...
# 2022-10-18  37.61     36.47     38.96     90.17      0.00
# 2022-10-19  39.69     38.54     41.30     85.83      0.00
# 2022-10-20  45.09     43.85     47.02     81.12      0.00
# 2022-10-21  51.45     50.26     53.24     82.42      0.00
# 2022-10-22  49.91     48.95     51.98     88.04      0.00
#
# [11983 rows x 5 columns]

# %%
furano_df.to_sql(name='furano', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 furano_df.to_sql(name='furano', con=engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1732, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1682 """
#    1683 Write records stored in a DataFrame to a SQL database.
#    1684
#    (...)
#    1728     Any additional kwargs are passed to the engine.
#    1729 """
#    1730 sql_engine = get_engine(engine)
# -> 1732 table = self.prep_table(
#    1733     frame=frame,
#    1734     name=name,
#    1735     if_exists=if_exists,
#    1736     index=index,
#    1737     index_label=index_label,
#    1738     schema=schema,
#    1739     dtype=dtype,
#    1740 )
#    1742 total_inserted = sql_engine.insert_records(
#    1743     table=table,
#    1744     con=self.connectable,
#    (...)
#    1751     **engine_kwargs,
#    1752 )
#    1754 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:834, in SQLTable.create(self)
#     832 if self.exists():
#     833     if self.if_exists == "fail":
# --> 834         raise ValueError(f"Table '{self.name}' already exists.")
#     835     elif self.if_exists == "replace":
#     836         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'furano' already exists.

# %%
# Import Zermat Data
zermatt_df = pd.read_csv('./cleaned_zermatt.csv')
zermatt_df
# Out:
#                dt   temp  temp_min  temp_max  humidity  snowfall
# 0      1990-01-01   6.01      5.08      7.02     50.62       0.0
# 1      1990-01-02  11.84      6.29     16.16     51.88       0.0
# 2      1990-01-03  14.34      6.50     19.59     42.88       0.0
# 3      1990-01-04  15.16      5.30     20.41     44.75       0.0
# 4      1990-01-05  13.71      5.18     18.52     44.17       0.0
# ...           ...    ...       ...       ...       ...       ...
# 11978  2022-10-18  50.55     44.43     53.48     69.17       0.0
# 11979  2022-10-19  52.29     43.86     54.81     42.29       0.0
# 11980  2022-10-20  48.57     43.60     50.21     74.25       0.0
# 11981  2022-10-21  46.00     42.57     47.43     97.38       0.0
# 11982  2022-10-22  47.58     44.03     49.81     85.25       0.0
#
# [11983 rows x 6 columns]

# %%
# Clean dt, and set as index, then drop column
zermatt_datetime = pd.to_datetime(zermatt_df['dt'])
zermatt_df = zermatt_df.set_index(zermatt_datetime)
zermatt_df = zermatt_df.drop(columns=['dt'])

# %%
zermatt_df.head(20)
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01   6.01      5.08      7.02     50.62       0.0
# 1990-01-02  11.84      6.29     16.16     51.88       0.0
# 1990-01-03  14.34      6.50     19.59     42.88       0.0
# 1990-01-04  15.16      5.30     20.41     44.75       0.0
# 1990-01-05  13.71      5.18     18.52     44.17       0.0
# 1990-01-06  15.77      7.55     19.32     66.50       0.0
# 1990-01-07  10.39      5.75     15.04     71.21       0.0
# 1990-01-08  12.28      5.62     16.88     43.46       0.0
# 1990-01-09  13.45      5.84     19.00     40.67       0.0
# 1990-01-10  15.99      7.94     20.33     57.79       0.0
# 1990-01-11  17.19      8.46     21.66     51.62       0.0
# 1990-01-12  17.55      8.15     21.86     43.12       0.0
# 1990-01-13  18.91      8.79     23.45     51.62       0.0
# 1990-01-14  19.05      8.87     22.86     67.50       0.0
# 1990-01-15  18.66     10.28     22.70     54.96       0.0
# 1990-01-16  34.11     20.47     38.42     64.21       0.0
# 1990-01-17  32.29     16.25     36.75     77.50       0.0
# 1990-01-18  24.92     13.74     28.71     74.96       0.0
# 1990-01-19  21.38     11.57     25.67     51.21       0.0
# 1990-01-20  24.56     12.66     28.80     32.96       0.0

# %%
zermatt_df.to_sql(name='zermatt', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 zermatt_df.to_sql(name='zermatt', con=engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1732, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1682 """
#    1683 Write records stored in a DataFrame to a SQL database.
#    1684
#    (...)
#    1728     Any additional kwargs are passed to the engine.
#    1729 """
#    1730 sql_engine = get_engine(engine)
# -> 1732 table = self.prep_table(
#    1733     frame=frame,
#    1734     name=name,
#    1735     if_exists=if_exists,
#    1736     index=index,
#    1737     index_label=index_label,
#    1738     schema=schema,
#    1739     dtype=dtype,
#    1740 )
#    1742 total_inserted = sql_engine.insert_records(
#    1743     table=table,
#    1744     con=self.connectable,
#    (...)
#    1751     **engine_kwargs,
#    1752 )
#    1754 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:834, in SQLTable.create(self)
#     832 if self.exists():
#     833     if self.if_exists == "fail":
# --> 834         raise ValueError(f"Table '{self.name}' already exists.")
#     835     elif self.if_exists == "replace":
#     836         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'zermatt' already exists.

# %%
# Import Tiffindell data
tiffindell_df = pd.read_csv('./cleaned_tiffindell.csv')
tiffindell_df.head(20)
# Out:
#             dt   temp  temp_min  temp_max  humidity  snowfall
# 0   1990-01-01  58.55     58.55     58.55     74.33       0.0
# 1   1990-01-02  60.58     60.58     60.58     76.46       0.0
# 2   1990-01-03  61.66     61.66     61.66     79.12       0.0
# 3   1990-01-04  62.28     62.28     62.28     69.67       0.0
# 4   1990-01-05  64.27     64.27     64.27     60.50       0.0
# 5   1990-01-06  62.63     62.63     62.63     63.79       0.0
# 6   1990-01-07  54.45     54.45     54.45     72.25       0.0
# 7   1990-01-08  56.67     56.67     56.67     66.21       0.0
# 8   1990-01-09  57.01     57.01     57.01     80.38       0.0
# 9   1990-01-10  48.67     48.67     48.67     89.67       0.0
# 10  1990-01-11  48.73     48.73     48.73     88.42       0.0
# 11  1990-01-12  55.75     55.75     55.75     76.58       0.0
# 12  1990-01-13  60.52     60.52     60.52     71.71       0.0
# 13  1990-01-14  60.74     60.74     60.74     75.04       0.0
# 14  1990-01-15  62.40     62.40     62.40     79.38       0.0
# 15  1990-01-16  57.62     57.62     57.62     90.21       0.0
# 16  1990-01-17  61.67     61.67     61.67     64.25       0.0
# 17  1990-01-18  65.69     65.69     65.69     51.50       0.0
# 18  1990-01-19  63.49     63.49     63.49     71.88       0.0
# 19  1990-01-20  56.78     56.78     56.78     81.08       0.0

# %%
# Clean dt, and set as index, then drop column
tiffindell_datetime = pd.to_datetime(tiffindell_df['dt'])
tiffindell_df = tiffindell_df.set_index(tiffindell_datetime)
tiffindell_df = tiffindell_df.drop(columns=['dt'])
tiffindell_df
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  58.55     58.55     58.55     74.33       0.0
# 1990-01-02  60.58     60.58     60.58     76.46       0.0
# 1990-01-03  61.66     61.66     61.66     79.12       0.0
# 1990-01-04  62.28     62.28     62.28     69.67       0.0
# 1990-01-05  64.27     64.27     64.27     60.50       0.0
# ...           ...       ...       ...       ...       ...
# 2022-10-18  57.24     57.24     57.24     64.67       0.0
# 2022-10-19  59.89     59.89     59.89     59.12       0.0
# 2022-10-20  58.99     58.99     58.99     68.83       0.0
# 2022-10-21  58.43     58.43     58.43     71.21       0.0
# 2022-10-22  49.58     49.58     49.58     92.96       0.0
#
# [11983 rows x 5 columns]

# %%
tiffindell_df.to_sql(name='tiffindell', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 tiffindell_df.to_sql(name='tiffindell', con=engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1732, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1682 """
#    1683 Write records stored in a DataFrame to a SQL database.
#    1684
#    (...)
#    1728     Any additional kwargs are passed to the engine.
#    1729 """
#    1730 sql_engine = get_engine(engine)
# -> 1732 table = self.prep_table(
#    1733     frame=frame,
#    1734     name=name,
#    1735     if_exists=if_exists,
#    1736     index=index,
#    1737     index_label=index_label,
#    1738     schema=schema,
#    1739     dtype=dtype,
#    1740 )
#    1742 total_inserted = sql_engine.insert_records(
#    1743     table=table,
#    1744     con=self.connectable,
#    (...)
#    1751     **engine_kwargs,
#    1752 )
#    1754 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:834, in SQLTable.create(self)
#     832 if self.exists():
#     833     if self.if_exists == "fail":
# --> 834         raise ValueError(f"Table '{self.name}' already exists.")
#     835     elif self.if_exists == "replace":
#     836         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'tiffindell' already exists.

# %% [markdown]
# ### Create a DataFrame with all the data to use for Machine Learning

# %%
# start with timberline append furano
test = finished_df.append(furano_df)
# Out:
# /var/folders/fz/l04x2xj91jb0dkt2t0wtld400000gn/T/ipykernel_33982/1889427715.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = finished_df.append(furano_df)

# %%
test
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  32.98     32.98     32.98     95.00     12.10
# 1990-01-02  27.54     27.54     27.54     91.50      9.90
# 1990-01-03  30.13     30.13     30.13     91.08      0.53
# 1990-01-04  34.82     34.82     34.82     91.79      4.85
# 1990-01-05  38.99     38.99     38.99     94.33      0.00
# ...           ...       ...       ...       ...       ...
# 2022-10-18  37.61     36.47     38.96     90.17      0.00
# 2022-10-19  39.69     38.54     41.30     85.83      0.00
# 2022-10-20  45.09     43.85     47.02     81.12      0.00
# 2022-10-21  51.45     50.26     53.24     82.42      0.00
# 2022-10-22  49.91     48.95     51.98     88.04      0.00
#
# [23966 rows x 5 columns]

# %%
# append craigieburn to timberline - furano
test = test.append(craigieburn_df)
# Out:
# /var/folders/fz/l04x2xj91jb0dkt2t0wtld400000gn/T/ipykernel_33982/3334948357.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = test.append(craigieburn_df)

# %%
test
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  32.98     32.98     32.98     95.00     12.10
# 1990-01-02  27.54     27.54     27.54     91.50      9.90
# 1990-01-03  30.13     30.13     30.13     91.08      0.53
# 1990-01-04  34.82     34.82     34.82     91.79      4.85
# 1990-01-05  38.99     38.99     38.99     94.33      0.00
# ...           ...       ...       ...       ...       ...
# 2022-10-18  39.62     39.62     39.62     72.33      0.00
# 2022-10-19  42.28     42.28     42.28     68.96      0.00
# 2022-10-20  41.10     41.10     41.10     71.50      0.00
# 2022-10-21  39.14     39.14     39.14     71.92      0.00
# 2022-10-22  50.54     50.54     50.54     57.54      0.00
#
# [35949 rows x 5 columns]

# %%
# append tiffindell to timberline furano and craigieburn
test = test.append(tiffindell_df)
# Out:
# /var/folders/fz/l04x2xj91jb0dkt2t0wtld400000gn/T/ipykernel_33982/75102966.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = test.append(tiffindell_df)

# %%
test
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  32.98     32.98     32.98     95.00     12.10
# 1990-01-02  27.54     27.54     27.54     91.50      9.90
# 1990-01-03  30.13     30.13     30.13     91.08      0.53
# 1990-01-04  34.82     34.82     34.82     91.79      4.85
# 1990-01-05  38.99     38.99     38.99     94.33      0.00
# ...           ...       ...       ...       ...       ...
# 2022-10-18  57.24     57.24     57.24     64.67      0.00
# 2022-10-19  59.89     59.89     59.89     59.12      0.00
# 2022-10-20  58.99     58.99     58.99     68.83      0.00
# 2022-10-21  58.43     58.43     58.43     71.21      0.00
# 2022-10-22  49.58     49.58     49.58     92.96      0.00
#
# [47932 rows x 5 columns]

# %%
# Append zermatt to timberline furano and craigieburn tiffindell
test = test.append(zermatt_df)
# Out:
# /var/folders/fz/l04x2xj91jb0dkt2t0wtld400000gn/T/ipykernel_33982/355998294.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test = test.append(zermatt_df)

# %%
test
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  32.98     32.98     32.98     95.00     12.10
# 1990-01-02  27.54     27.54     27.54     91.50      9.90
# 1990-01-03  30.13     30.13     30.13     91.08      0.53
# 1990-01-04  34.82     34.82     34.82     91.79      4.85
# 1990-01-05  38.99     38.99     38.99     94.33      0.00
# ...           ...       ...       ...       ...       ...
# 2022-10-18  50.55     44.43     53.48     69.17      0.00
# 2022-10-19  52.29     43.86     54.81     42.29      0.00
# 2022-10-20  48.57     43.60     50.21     74.25      0.00
# 2022-10-21  46.00     42.57     47.43     97.38      0.00
# 2022-10-22  47.58     44.03     49.81     85.25      0.00
#
# [59915 rows x 5 columns]

# %%
# Import valle nevado data
valle_df = pd.read_csv('./cleaned_Valle_Nevado_df.csv')

# %%
valle_df
# Out:
#                dt   temp  temp_min  temp_max  humidity  snowfall
# 0      1990-01-01  51.52     42.37     65.42     57.54       0.0
# 1      1990-01-02  50.55     39.14     69.13     57.04       0.0
# 2      1990-01-03  52.62     43.07     68.73     59.42       0.0
# 3      1990-01-04  53.63     42.83     71.49     56.33       0.0
# 4      1990-01-05  54.17     44.52     70.89     61.54       0.0
# ...           ...    ...       ...       ...       ...       ...
# 11978  2022-10-18  32.11     26.89     34.64     62.96       0.0
# 11979  2022-10-19  31.18     26.45     33.50     61.00       0.0
# 11980  2022-10-20  35.68     31.36     39.19     39.46       0.0
# 11981  2022-10-21  39.40     34.36     43.16     35.50       0.0
# 11982  2022-10-22  40.25     34.84     43.53     30.46       0.0
#
# [11983 rows x 6 columns]

# %%
# Clean valle nevado data change dt to date xxxx/xx/xx make date index and drop dt column
valle_datetime = pd.to_datetime(valle_df['dt'])
valle_df = valle_df.set_index(valle_datetime)
valle_df = valle_df.drop(columns=['dt'])

# %%
valle_df
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  51.52     42.37     65.42     57.54       0.0
# 1990-01-02  50.55     39.14     69.13     57.04       0.0
# 1990-01-03  52.62     43.07     68.73     59.42       0.0
# 1990-01-04  53.63     42.83     71.49     56.33       0.0
# 1990-01-05  54.17     44.52     70.89     61.54       0.0
# ...           ...       ...       ...       ...       ...
# 2022-10-18  32.11     26.89     34.64     62.96       0.0
# 2022-10-19  31.18     26.45     33.50     61.00       0.0
# 2022-10-20  35.68     31.36     39.19     39.46       0.0
# 2022-10-21  39.40     34.36     43.16     35.50       0.0
# 2022-10-22  40.25     34.84     43.53     30.46       0.0
#
# [11983 rows x 5 columns]

# %%
# append valle nevado to timberline furano craigieburn tiffindell zermatt
ml_df = test.append(valle_df)
# Out:
# /var/folders/fz/l04x2xj91jb0dkt2t0wtld400000gn/T/ipykernel_33982/1384482892.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ml_df = test.append(valle_df)

# %%
ml_df
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  32.98     32.98     32.98     95.00     12.10
# 1990-01-02  27.54     27.54     27.54     91.50      9.90
# 1990-01-03  30.13     30.13     30.13     91.08      0.53
# 1990-01-04  34.82     34.82     34.82     91.79      4.85
# 1990-01-05  38.99     38.99     38.99     94.33      0.00
# ...           ...       ...       ...       ...       ...
# 2022-10-18  32.11     26.89     34.64     62.96      0.00
# 2022-10-19  31.18     26.45     33.50     61.00      0.00
# 2022-10-20  35.68     31.36     39.19     39.46      0.00
# 2022-10-21  39.40     34.36     43.16     35.50      0.00
# 2022-10-22  40.25     34.84     43.53     30.46      0.00
#
# [71898 rows x 5 columns]

# %%
# Replace values of snowfall 1 (yes) 0 (no) of Given column by using np.where() function.
ml_df['snowfall'] = np.where(ml_df['snowfall'] > 0, 1, ml_df['snowfall'])

# %%
#Use get_dummies to get rid of the decimal in ml_df snowfall column
dummies_column = pd.get_dummies(ml_df['snowfall'])
dummies_column
# Out:
#             0.0  1.0
# dt
# 1990-01-01    0    1
# 1990-01-02    0    1
# 1990-01-03    0    1
# 1990-01-04    0    1
# 1990-01-05    1    0
# ...         ...  ...
# 2022-10-18    1    0
# 2022-10-19    1    0
# 2022-10-20    1    0
# 2022-10-21    1    0
# 2022-10-22    1    0
#
# [71898 rows x 2 columns]

# %%
# make snowfall coulumn = column '1.0' of dummies_column
ml_df['snowfall'] = dummies_column[1]
ml_df
# Out:
#              temp  temp_min  temp_max  humidity  snowfall
# dt
# 1990-01-01  32.98     32.98     32.98     95.00         1
# 1990-01-02  27.54     27.54     27.54     91.50         1
# 1990-01-03  30.13     30.13     30.13     91.08         1
# 1990-01-04  34.82     34.82     34.82     91.79         1
# 1990-01-05  38.99     38.99     38.99     94.33         0
# ...           ...       ...       ...       ...       ...
# 2022-10-18  32.11     26.89     34.64     62.96         0
# 2022-10-19  31.18     26.45     33.50     61.00         0
# 2022-10-20  35.68     31.36     39.19     39.46         0
# 2022-10-21  39.40     34.36     43.16     35.50         0
# 2022-10-22  40.25     34.84     43.53     30.46         0
#
# [71898 rows x 5 columns]

# %%
ml_df.to_csv('./ml_df.csv')
