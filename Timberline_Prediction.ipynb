# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load CSV File
timberline_ml_df = pd.read_csv('./Timberline_SnowFall.csv')
timberline_ml_df
# Out:
#     year  total_snowfall
# 0   1990          529.46
# 1   1991          384.42
# 2   1992          389.71
# 3   1993          393.83
# 4   1994          528.37
# 5   1995          382.53
# 6   1996          827.65
# 7   1997          389.50
# 8   1998          532.64
# 9   1999          670.18
# 10  2000          635.06
# 11  2001          470.25
# 12  2002          551.02
# 13  2003          575.82
# 14  2004          453.07
# 15  2005          382.95
# 16  2006          604.33
# 17  2007          529.74
# 18  2008          768.65
# 19  2009          524.51
# 20  2010          503.22
# 21  2011          424.24
# 22  2012          763.39
# 23  2013          397.74
# 24  2014          700.74
# 25  2015          286.62
# 26  2016          461.72
# 27  2017          536.61
# 28  2018          664.44
# 29  2019         1055.64
# 30  2020         1197.35
# 31  2021         1625.90
# 32  2022         1086.94

# %%
# Drop the last row, as 2022 isn't finished yet
timberline_ml_df.drop(timberline_ml_df.tail(1).index, inplace=True)
timberline_ml_df
# Out:
#     year  total_snowfall
# 0   1990          529.46
# 1   1991          384.42
# 2   1992          389.71
# 3   1993          393.83
# 4   1994          528.37
# 5   1995          382.53
# 6   1996          827.65
# 7   1997          389.50
# 8   1998          532.64
# 9   1999          670.18
# 10  2000          635.06
# 11  2001          470.25
# 12  2002          551.02
# 13  2003          575.82
# 14  2004          453.07
# 15  2005          382.95
# 16  2006          604.33
# 17  2007          529.74
# 18  2008          768.65
# 19  2009          524.51
# 20  2010          503.22
# 21  2011          424.24
# 22  2012          763.39
# 23  2013          397.74
# 24  2014          700.74
# 25  2015          286.62
# 26  2016          461.72
# 27  2017          536.61
# 28  2018          664.44
# 29  2019         1055.64
# 30  2020         1197.35
# 31  2021         1625.90

# %%
# Visually Inspect the relationship between Snowfall and Years
plt.scatter(timberline_ml_df.year, timberline_ml_df.total_snowfall)
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
# Format data to meet requirements of the Scikit-learn library
X = timberline_ml_df.year.values.reshape(-1, 1)

# %%
# Assign the y value
y = timberline_ml_df.total_snowfall

# %%
# Create an instance of the linear regression model
model = LinearRegression()

# %%
# Fit the model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Generate predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (32,)

# %%
# Plot the predictions as a red line against the data points
plt.scatter(X,y)
plt.plot(X, y_pred, color='red')
plt.title("Predicting Snowfall in Timberline")
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
#Examine slope and y-intercept
print(model.coef_)
print(model.intercept_)
# Out:
# [14.21735704]
# -27914.743914956027
