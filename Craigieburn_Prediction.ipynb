# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
craigieburn_ml_df = pd.read_csv('./Craigieburn_SnowFall.csv')
craigieburn_ml_df
# Out:
#     year  total_snowfall
# 0   1990          264.26
# 1   1991          230.82
# 2   1992          558.21
# 3   1993          263.48
# 4   1994          307.03
# 5   1995          483.51
# 6   1996          315.44
# 7   1997          260.09
# 8   1998          173.76
# 9   1999          252.44
# 10  2000          231.68
# 11  2001          204.57
# 12  2002          245.79
# 13  2003          318.45
# 14  2004          358.99
# 15  2005          156.19
# 16  2006          388.81
# 17  2007          226.03
# 18  2008          397.26
# 19  2009          352.10
# 20  2010          324.45
# 21  2011          261.87
# 22  2012          379.37
# 23  2013          261.72
# 24  2014          136.87
# 25  2015          302.55
# 26  2016          227.06
# 27  2017          254.89
# 28  2018          243.87
# 29  2019          242.99
# 30  2020          247.58
# 31  2021          154.77
# 32  2022          348.84

# %%
# Drop the last row, as 2022 isn't finished yet
craigieburn_ml_df.drop(craigieburn_ml_df.tail(1).index, inplace=True)
craigieburn_ml_df
# Out:
#     year  total_snowfall
# 0   1990          264.26
# 1   1991          230.82
# 2   1992          558.21
# 3   1993          263.48
# 4   1994          307.03
# 5   1995          483.51
# 6   1996          315.44
# 7   1997          260.09
# 8   1998          173.76
# 9   1999          252.44
# 10  2000          231.68
# 11  2001          204.57
# 12  2002          245.79
# 13  2003          318.45
# 14  2004          358.99
# 15  2005          156.19
# 16  2006          388.81
# 17  2007          226.03
# 18  2008          397.26
# 19  2009          352.10
# 20  2010          324.45
# 21  2011          261.87
# 22  2012          379.37
# 23  2013          261.72
# 24  2014          136.87
# 25  2015          302.55
# 26  2016          227.06
# 27  2017          254.89
# 28  2018          243.87
# 29  2019          242.99
# 30  2020          247.58
# 31  2021          154.77

# %%
# Visually Inspect the relationship between Snowfall and Years
plt.scatter(craigieburn_ml_df.year, craigieburn_ml_df.total_snowfall)
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
# Format data to meet requirements of the Scikit-learn library
X = craigieburn_ml_df.year.values.reshape(-1, 1)

# %%
# Assign the y value
y = craigieburn_ml_df.total_snowfall

# %%
# Create an instance of the linear regression model
model = LinearRegression()

# %%
# Fit the model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Generate predictions
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (32,)

# %%
# Plot the predictions as a red line against the data points
plt.scatter(X,y)
plt.plot(X, y_pred, color='red')
plt.title("Predicting Snowfall in Craigieburn")
plt.xlabel('Year')
plt.ylabel('Snowfall(in inches)')
plt.show()

# %%
#Examine slope and y-intercept
print(model.coef_)
print(model.intercept_)
# Out:
# [-2.83746334]
# 5972.6233596041075
