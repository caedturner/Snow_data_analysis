# %%
# Import dependancies 
import pandas as pd

# %%
# Locate data
Furano_Ski_Resort_to_load = "C:\\Users\\haley\\Desktop\\Snow_data_analysis\\Resources\\Furano_Ski_Resort.csv"

# %%
#Read the Craigieburn_Valley data
Furano_Ski_Resort_df = pd.read_csv(Furano_Ski_Resort_to_load)

# %%
Furano_Ski_Resort_df
# Out:
#                 dt                         dt_iso  timezone  \
# 0        631152000  1990-01-01 00:00:00 +0000 UTC     32400
# 1        631155600  1990-01-01 01:00:00 +0000 UTC     32400
# 2        631159200  1990-01-01 02:00:00 +0000 UTC     32400
# 3        631162800  1990-01-01 03:00:00 +0000 UTC     32400
# 4        631166400  1990-01-01 04:00:00 +0000 UTC     32400
# ...            ...                            ...       ...
# 287587  1666465200  2022-10-22 19:00:00 +0000 UTC     32400
# 287588  1666468800  2022-10-22 20:00:00 +0000 UTC     32400
# 287589  1666472400  2022-10-22 21:00:00 +0000 UTC     32400
# 287590  1666476000  2022-10-22 22:00:00 +0000 UTC     32400
# 287591  1666479600  2022-10-22 23:00:00 +0000 UTC     32400
#
#                 city_name        lat         lon   temp  visibility  \
# 0       Furano ski resort  43.324632  142.354126   7.38         NaN
# 1       Furano ski resort  43.324632  142.354126  12.74         NaN
# ...
